# %%
import sys
sys.path.append("../prog")
import cauFirst

# %%
#!/usr/bin/env python
# coding: utf-8



import yaml
import sys
import copy

from collections import OrderedDict

if True:
    def represent_odict(dumper, instance):
        return dumper.represent_mapping('tag:yaml.org,2002:map', instance.items())

    yaml.add_representer(OrderedDict, represent_odict)

    def construct_odict(loader, node):
        return OrderedDict(loader.construct_pairs(node))

    yaml.add_constructor('tag:yaml.org,2002:map', construct_odict)

class FDTreeSet(object):
    def __init__(self):
        self.wfblockall = []
        self.lkblockall = []

    def load(self,filename):
        data = None
        with open(filename) as f:
            data = yaml.safe_load(f)
        return data

    def apply_link(self,data,filename):
        key1 = "link"
        linkcontent = ["nodename","nodetype","linktype"]
        linklist =  []
        for link in data[key1]:
            alink = []
            for content in linkcontent:
                if content in link.keys():
                    alink.append( (content,link[content]) )
            alink.append( ("filename",filename) )
            if "link" in link.keys():
                newlink = apply_link(link,filename)
                alink.append( ("link", newlink ) )
            linklist.append(  OrderedDict(alink) )
        return linklist

    def wf_add_tag_filename(self,blocklist,filename=None):


        wfblockall = []
        for i,wf in enumerate(blocklist):

            if wf["blockname"] is None or len(wf["blockname"])==0:
                wf["blockname"] = "{}#{}".format(filename,i)
            wf.update({"filename":filename})
            wfblockall.append( copy.deepcopy(wf) )

        return wfblockall

    def lk_add_tag_filename(self,blocklist):
        linkblockall = []
        for link in blocklist:

            #link.update({"filename":filename})
            #linkblockall.extend(apply_link(link,filename) )
            linkblockall.extend(link )
        return linkblockall

    def load_files(self,filenames):
        dataall = {}

        wfblockall = self.wfblockall
        lkblockall = self.lkblockall

        for filename in filenames:
          data = self.load(filename)

          for key in data:
              if key=="workflow":
                  data = self.wf_add_tag_filename(data[key]["block"],filename)
                  wfblockall.extend(data)
              elif key=="linkset":
                  #data = lk_add_tag_filename(data[key]["block"],filename)
                  ablock = data[key]["block"]
                  lkblockall.extend(ablock)

        self.wfblockall = wfblockall
        self.lkblockall = lkblockall
        

        #output = OrderedDict([("workflow",{ "block": wfblockall}), ("linkset",{"block": lkblockall} )] )
        #return output
    
    def export_dic(self):
        wfblockall = self.wfblockall
        lkblockall = self.lkblockall
        output = OrderedDict([("workflow",{ "block": wfblockall}), ("linkset",{"block": lkblockall} )] )
        return output
    
    def print_wf(self):
        for x in self.wfblockall:
            print("workflow:",x["blockname"])
            
    def print_lk(self):
        for x in self.lkblockall:
            print("link:",x["link"][0]["nodename"])
            
    def print_names(self,name=None):
        if name is None:
            self.print_wf()
            self.print_lk()
        if name in ["wf"]:
            self.print_wf()
        if name in ["lk"]:
            self.print_lk()

# %%
fdtset = FDTreeSet()

# %%
import glob
filenames = glob.glob("../sample/CrystalTargetToDescriptor_*.yml")
print(filenames)
# Out:
# ['../sample/CrystalTargetToDescriptor_Misc.yml', '../sample/CrystalTargetToDescriptor_Top.yml']

# %%
import glob
filenames = ["../sample/MaterialsList_CrystalCandidates.yml",
            "../sample/MaterialsList_RegressionModel.yml",
             "../sample/MaterialsList_SearchGoodMaterial.yml",
             "../sample/MaterialsList_TrainingSet.yml",
             "../sample/MaterialsList_aquisitionFunction.yml"
            ]

# %%
fdtset.load_files(filenames)

# %%
fdtset.print_names()
# Out:
# workflow: random generation
# workflow: random generation
# workflow: mateirals knowledge
# workflow: mateirals knowledge Target variable
# workflow: mateirals knowledge Target variable
# workflow: ../sample/MaterialsList_RegressionModel.yml#0
# workflow: ../sample/MaterialsList_RegressionModel.yml#1
# workflow: ../sample/MaterialsList_RegressionModel.yml#2
# workflow: ../sample/MaterialsList_SearchGoodMaterial.yml#0
# workflow: ../sample/MaterialsList_SearchGoodMaterial.yml#1
# workflow: ../sample/MaterialsList_SearchGoodMaterial.yml#2
# workflow: ../sample/MaterialsList_TrainingSet.yml#0
# workflow: ../sample/MaterialsList_TrainingSet.yml#1
# workflow: ../sample/MaterialsList_TrainingSet.yml#2
# workflow: ../sample/MaterialsList_TrainingSet.yml#3
# workflow: ../sample/MaterialsList_aquisitionFunction.yml#0
# workflow: ../sample/MaterialsList_aquisitionFunction.yml#1

# %%
fdtree = cauFirst.FDTree()

# %%
fdtree.apply(fdtset.export_dic())
# Out:
# png is made.

# %%
fdtset.wfblockall
# Out:
# [{'blockname': 'random generation',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'MaterialsKnowledge',
#       'outputtype': 'method'}]},
#    {'group': [{'methodname': 'randomGeneration',
#       'methodtype': 'method',
#       'outputname': 'NewsetCrystal',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_CrystalCandidates.yml'},
#  {'blockname': 'random generation',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'existingCrystals',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'substituteElements',
#       'methodtype': 'function',
#       'outputname': 'NewsetCrystal',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_CrystalCandidates.yml'},
#  {'blockname': 'mateirals knowledge',
#   'order': 'workflow',
#   'list': [{'group': [{'methodname': 'MaterialsDatabase',
#       'methodtype': 'method',
#       'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'},
#      {'outputname': 'chooseMaterialSystem', 'outputtype': 'function'}]},
#    {'group': [{'methodname': 'CrystalsFromDatabase',
#       'methodtype': 'parts',
#       'outputname': 'existingCrystals',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'getParticularQuantities',
#       'methodtype': 'function',
#       'outputname': 'MaterialsKnowledge',
#       'outputtype': 'method'}]}],
#   'filename': '../sample/MaterialsList_CrystalCandidates.yml'},
#  {'blockname': 'mateirals knowledge Target variable',
#   'order': 'workflow',
#   'list': [{'group': [{'methodname': 'MaterialsDatabase',
#       'methodtype': 'method',
#       'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'TargetValuesFromDatabase',
#       'methodtype': 'parts',
#       'outputname': 'chooseTargetValues',
#       'outputtype': 'function'}]}],
#   'filename': '../sample/MaterialsList_CrystalCandidates.yml'},
#  {'blockname': 'mateirals knowledge Target variable',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'},
#      {'outputname': 'chooseCrystals', 'outputtype': 'function'}]},
#    {'group': [{'methodname': 'CrystalsFromDatabase',
#       'methodtype': 'parts',
#       'outputname': 'existingCrystals',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_CrystalCandidates.yml'},
#  {'blockname': '../sample/MaterialsList_RegressionModel.yml#0',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'TrainingData', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'NeuralNetworkRegression',
#       'outputname': 'RegressionModel',
#       'outputtype': 'parts'},
#      {'methodname': 'LinearRegression',
#       'outputname': 'RegressionModel',
#       'outputtype': 'parts'},
#      {'methodname': 'KernelRegression',
#       'outputname': 'RegressionModel',
#       'outputtype': 'parts'},
#      {'methodname': 'RandomForestRegression',
#       'outputname': 'RegressionModel',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_RegressionModel.yml'},
#  {'blockname': '../sample/MaterialsList_RegressionModel.yml#1',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'RegressionModel', 'outputtype': 'parts'},
#      {'outputname': 'NewsetDescriptor', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'evaluateRegressionModel',
#       'methodtype': 'function',
#       'outputname': 'RegressionModelValues',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'sortRegressionModelValues',
#       'methodtype': 'function',
#       'outputname': 'raiseMaterialsList',
#       'outputtype': 'function'}]}],
#   'filename': '../sample/MaterialsList_RegressionModel.yml'},
#  {'blockname': '../sample/MaterialsList_RegressionModel.yml#2',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'NewsetCrystal', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'CrystalToDescriptorAndRelationToTargetVariable(newSet)',
#       'methodtype': 'method',
#       'outputname': 'NewsetDescriptor',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_RegressionModel.yml'},
#  {'blockname': '../sample/MaterialsList_SearchGoodMaterial.yml#0',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'raiseMaterialsList',
#       'outputtype': 'function'},
#      {'outputname': 'searchMaterialsListHavingTargetVariable',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'selectNoExperiment',
#       'methodtype': 'function',
#       'outputname': 'NoExperimentMaterialsList',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'MaterialSynthesis',
#       'methodtype': 'method',
#       'outputname': 'SynthesizedMaterils',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'measureTargetQuanitty',
#       'methodtype': 'function',
#       'outputname': 'newTargetValues',
#       'outputtype': 'parts'},
#      {'methodname': 'TargetSelectionCriterion',
#       'methodtype': 'parts',
#       'outputname': 'getTargetSelectionCriterion',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'SelectSynthesizedTaretMaterialsIteratively',
#       'methodtype': 'function',
#       'outputname': 'newTargetMaterial',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_SearchGoodMaterial.yml'},
#  {'blockname': '../sample/MaterialsList_SearchGoodMaterial.yml#1',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'TargetCriterion',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'TargetSelectionCriterion',
#       'methodtype': 'parts',
#       'outputname': 'getTargetSelectionCriterion',
#       'outputtype': 'function'}]}],
#   'filename': '../sample/MaterialsList_SearchGoodMaterial.yml'},
#  {'blockname': '../sample/MaterialsList_SearchGoodMaterial.yml#2',
#   'order': 'workflow',
#   'list': [{'group': [{'methodname': 'MaterialsDatabase',
#       'methodtype': 'method',
#       'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'},
#      {'outputname': 'chooseTargetValues', 'outputtype': 'function'}]},
#    {'group': [{'methodname': 'storeInMaterialsDataBase',
#       'methodtype': 'function',
#       'outputname': 'RicherMaterialsDatabase',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_SearchGoodMaterial.yml'},
#  {'blockname': '../sample/MaterialsList_TrainingSet.yml#0',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'searchCrystalHavingTargetValuesfromDatabase',
#       'methodtype': 'function',
#       'outputname': 'chooseTrainingSetCrystal',
#       'outputtype': 'function'}]}],
#   'filename': '../sample/MaterialsList_TrainingSet.yml'},
#  {'blockname': '../sample/MaterialsList_TrainingSet.yml#1',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'chooseMaterialsDatabase',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'queryCrysalDataHavingTarget',
#       'methodtype': 'function',
#       'outputname': 'CrystalHavingTargetValuesFromDatabase',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'chooseTargetValues',
#       'methodtype': 'parts',
#       'outputname': 'TargetValues',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_TrainingSet.yml'},
#  {'blockname': '../sample/MaterialsList_TrainingSet.yml#2',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'chooseTrainingSetCrystal',
#       'outputtype': 'function'}]},
#    {'group': [{'methodname': 'CrystalToDescriptorAndRelationToTargetVariable(trainingSet)',
#       'methodtype': 'method',
#       'outputname': 'TrainingSetDescriptorAndRelationToTargetVariable',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_TrainingSet.yml'},
#  {'blockname': '../sample/MaterialsList_TrainingSet.yml#3',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'TrainingSetDescriptorAndRelationToTargetVariable',
#       'outputtype': 'parts'},
#      {'outputname': 'TargetValues', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'TrainingDataGeneration',
#       'methodtype': 'method',
#       'outputname': 'TrainingData',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_TrainingSet.yml'},
#  {'blockname': '../sample/MaterialsList_aquisitionFunction.yml#0',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'TrainingData', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'fitBayesianLinearRegression',
#       'methodtype': 'function',
#       'outputname': 'BayesianLinearRegression',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'applyBayesianLinearRegression',
#       'methodtype': 'function',
#       'outputname': 'PredictionMeanAndVariance',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'UCBaquisitionFunction',
#       'methodtype': 'parts',
#       'outputname': 'aquisitionFunctionValues',
#       'outputtype': 'parts'},
#      {'methodname': 'ThonpsonSamplingaquisitionFunction',
#       'methodtype': 'parts',
#       'outputname': 'aquisitionFunctionValues',
#       'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'sortAquisitionFunctionValues',
#       'methodtype': 'function',
#       'outputname': 'raiseMaterialsList',
#       'outputtype': 'function'}]}],
#   'filename': '../sample/MaterialsList_aquisitionFunction.yml'},
#  {'blockname': '../sample/MaterialsList_aquisitionFunction.yml#1',
#   'order': 'workflow',
#   'list': [{'group': [{'outputname': 'BayesianLinearRegression',
#       'outputtype': 'parts'},
#      {'outputname': 'NewsetDescriptor', 'outputtype': 'parts'}]},
#    {'group': [{'methodname': 'apply_BayesianLinearRegression',
#       'methodtype': 'function',
#       'outputname': 'PredictionMeanAndVariance',
#       'outputtype': 'parts'}]}],
#   'filename': '../sample/MaterialsList_aquisitionFunction.yml'}]

# %%
class wfblockTowfChaim(object):
    def __init__(self,wfblockall):
        
        wklist = self.wfblockallTowklist(wfblockall)        
        wklist.extend( self.wfblockallTowklist_fromLast(wfblockall) )
    
        self.wklist = wklist
        
    def wfblockallTowklist(self,wfblockall):
        #wfblockall = self.wfblockall
        wklist = []
        for block in wfblockall:
            blockname = block["blockname"]
            for alist1,alist2 in zip(block["list"][0:-1],block["list"][1:]):
                #print(">",alist1,alist2)
                group1 = alist1["group"]
                group2 = alist2["group"]
                for node1 in group1:
                    for node2 in group2:
                        wklist.append([copy.deepcopy(node1),copy.deepcopy(node2)])
        return wklist
    
    def search_connection(self,node):
        wklist = []
        outputname = node["outputname"]
        outputtype = None
        if "outputtype" in node:
            outputtype = node["outputtype"]
        for block in fdtset.wfblockall:
            blockname = block["blockname"]
            for alist1,alist2 in zip(block["list"][0:-1],block["list"][1:]):
                group1 = alist1["group"]
                group2 = alist2["group"]
                for node1 , node2 in zip(group1,group2):
                    wklist.append([node1,node2])
                    if node1["outputname"] == node["outputname"] and \
                       node1["outputtype"] == node["outputtype"]:
                            #print("found>", node1,"->",node2)
                            wklist.append( [node1,node2])
        return wklist    
    
    def wfblockallTowklist_fromLast(self,wfblockall):
        #wfblockall = self.wfblockall
        wklist = []
        for block in wfblockall:
            blockname = block["blockname"]
            alist1 = block["list"][-1]["group"]
            #print (alist1)
            for node in alist1:
                outputname = node["outputname"]
                outputtype = None
                if "outputtype" in node:
                    outputtype = node["outputtype"]
                #print(outputname,outputtype)
                wklist.extend(self.search_connection(node))
        return wklist
    
    def wklistToWF(self):
        wklist = self.wklist
        blocklist = []
        for wk in wklist:
            node1,node2 = wk
            if "methodname"  not in node2:
                print(node1)
                print(node2)
                raise
            name = node1["outputname"]+"-"+node2["methodname"]+"-"+node2["outputname"]
            gglist = OrderedDict( ( ("blockname", name),\
                                   ("order","workflow"),\
                      ("list", [{"group":[node1]}, {"group":[node2]} ] ) ) )
            blocklist.append(gglist)

        blocks = OrderedDict( ( ("format", "v2.3"), \
            ("block", blocklist) ) )
        wf = OrderedDict( {"workflow":blocks} )

        return wf
    
wfchain = wfblockTowfChaim(fdtset.wfblockall)

# %%
wf = wfchain.wklistToWF()
print(yaml.dump(wf))
# Out:
# workflow:
#   format: v2.3
#   block:
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - outputname: MaterialsKnowledge
#         outputtype: method
#     - group:
#       - methodname: randomGeneration
#         methodtype: method
#         outputname: NewsetCrystal
#         outputtype: parts
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - outputname: existingCrystals
#         outputtype: parts
#     - group:
#       - methodname: substituteElements
#         methodtype: function
#         outputname: NewsetCrystal
#         outputtype: parts
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: chooseMaterialSystem-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseMaterialSystem
#         outputtype: function
#     - group:
#       - methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#     - group:
#       - methodname: getParticularQuantities
#         methodtype: function
#         outputname: MaterialsKnowledge
#         outputtype: method
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: TargetValuesFromDatabase
#         methodtype: parts
#         outputname: chooseTargetValues
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: chooseCrystals-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseCrystals
#         outputtype: function
#     - group:
#       - methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingData
#         outputtype: parts
#     - group:
#       - methodname: NeuralNetworkRegression
#         outputname: RegressionModel
#         outputtype: parts
#   - blockname: TrainingData-LinearRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingData
#         outputtype: parts
#     - group:
#       - methodname: LinearRegression
#         outputname: RegressionModel
#         outputtype: parts
#   - blockname: TrainingData-KernelRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingData
#         outputtype: parts
#     - group:
#       - methodname: KernelRegression
#         outputname: RegressionModel
#         outputtype: parts
#   - blockname: TrainingData-RandomForestRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingData
#         outputtype: parts
#     - group:
#       - methodname: RandomForestRegression
#         outputname: RegressionModel
#         outputtype: parts
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - outputname: RegressionModel
#         outputtype: parts
#     - group:
#       - methodname: evaluateRegressionModel
#         methodtype: function
#         outputname: RegressionModelValues
#         outputtype: function
#   - blockname: NewsetDescriptor-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - outputname: NewsetDescriptor
#         outputtype: parts
#     - group:
#       - methodname: evaluateRegressionModel
#         methodtype: function
#         outputname: RegressionModelValues
#         outputtype: function
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - methodname: evaluateRegressionModel
#         methodtype: function
#         outputname: RegressionModelValues
#         outputtype: function
#     - group:
#       - methodname: sortRegressionModelValues
#         methodtype: function
#         outputname: raiseMaterialsList
#         outputtype: function
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - outputname: NewsetCrystal
#         outputtype: parts
#     - group:
#       - methodname: CrystalToDescriptorAndRelationToTargetVariable(newSet)
#         methodtype: method
#         outputname: NewsetDescriptor
#         outputtype: parts
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - outputname: raiseMaterialsList
#         outputtype: function
#     - group:
#       - methodname: selectNoExperiment
#         methodtype: function
#         outputname: NoExperimentMaterialsList
#         outputtype: parts
#   - blockname: searchMaterialsListHavingTargetVariable-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - outputname: searchMaterialsListHavingTargetVariable
#         outputtype: function
#     - group:
#       - methodname: selectNoExperiment
#         methodtype: function
#         outputname: NoExperimentMaterialsList
#         outputtype: parts
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - methodname: selectNoExperiment
#         methodtype: function
#         outputname: NoExperimentMaterialsList
#         outputtype: parts
#     - group:
#       - methodname: MaterialSynthesis
#         methodtype: method
#         outputname: SynthesizedMaterils
#         outputtype: parts
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - methodname: MaterialSynthesis
#         methodtype: method
#         outputname: SynthesizedMaterils
#         outputtype: parts
#     - group:
#       - methodname: measureTargetQuanitty
#         methodtype: function
#         outputname: newTargetValues
#         outputtype: parts
#   - blockname: SynthesizedMaterils-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - methodname: MaterialSynthesis
#         methodtype: method
#         outputname: SynthesizedMaterils
#         outputtype: parts
#     - group:
#       - methodname: TargetSelectionCriterion
#         methodtype: parts
#         outputname: getTargetSelectionCriterion
#         outputtype: function
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - methodname: measureTargetQuanitty
#         methodtype: function
#         outputname: newTargetValues
#         outputtype: parts
#     - group:
#       - methodname: SelectSynthesizedTaretMaterialsIteratively
#         methodtype: function
#         outputname: newTargetMaterial
#         outputtype: parts
#   - blockname: getTargetSelectionCriterion-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - methodname: TargetSelectionCriterion
#         methodtype: parts
#         outputname: getTargetSelectionCriterion
#         outputtype: function
#     - group:
#       - methodname: SelectSynthesizedTaretMaterialsIteratively
#         methodtype: function
#         outputname: newTargetMaterial
#         outputtype: parts
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - outputname: TargetCriterion
#         outputtype: parts
#     - group:
#       - methodname: TargetSelectionCriterion
#         methodtype: parts
#         outputname: getTargetSelectionCriterion
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: storeInMaterialsDataBase
#         methodtype: function
#         outputname: RicherMaterialsDatabase
#         outputtype: parts
#   - blockname: chooseTargetValues-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseTargetValues
#         outputtype: function
#     - group:
#       - methodname: storeInMaterialsDataBase
#         methodtype: function
#         outputname: RicherMaterialsDatabase
#         outputtype: parts
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: searchCrystalHavingTargetValuesfromDatabase
#         methodtype: function
#         outputname: chooseTrainingSetCrystal
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - methodname: queryCrysalDataHavingTarget
#         methodtype: function
#         outputname: CrystalHavingTargetValuesFromDatabase
#         outputtype: parts
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - methodname: queryCrysalDataHavingTarget
#         methodtype: function
#         outputname: CrystalHavingTargetValuesFromDatabase
#         outputtype: parts
#     - group:
#       - methodname: chooseTargetValues
#         methodtype: parts
#         outputname: TargetValues
#         outputtype: parts
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - outputname: chooseTrainingSetCrystal
#         outputtype: function
#     - group:
#       - methodname: CrystalToDescriptorAndRelationToTargetVariable(trainingSet)
#         methodtype: method
#         outputname: TrainingSetDescriptorAndRelationToTargetVariable
#         outputtype: parts
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingSetDescriptorAndRelationToTargetVariable
#         outputtype: parts
#     - group:
#       - methodname: TrainingDataGeneration
#         methodtype: method
#         outputname: TrainingData
#         outputtype: parts
#   - blockname: TargetValues-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - outputname: TargetValues
#         outputtype: parts
#     - group:
#       - methodname: TrainingDataGeneration
#         methodtype: method
#         outputname: TrainingData
#         outputtype: parts
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - outputname: TrainingData
#         outputtype: parts
#     - group:
#       - methodname: fitBayesianLinearRegression
#         methodtype: function
#         outputname: BayesianLinearRegression
#         outputtype: parts
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - methodname: fitBayesianLinearRegression
#         methodtype: function
#         outputname: BayesianLinearRegression
#         outputtype: parts
#     - group:
#       - methodname: applyBayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - methodname: applyBayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#     - group:
#       - methodname: UCBaquisitionFunction
#         methodtype: parts
#         outputname: aquisitionFunctionValues
#         outputtype: parts
#   - blockname: PredictionMeanAndVariance-ThonpsonSamplingaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - methodname: applyBayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#     - group:
#       - methodname: ThonpsonSamplingaquisitionFunction
#         methodtype: parts
#         outputname: aquisitionFunctionValues
#         outputtype: parts
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - methodname: UCBaquisitionFunction
#         methodtype: parts
#         outputname: aquisitionFunctionValues
#         outputtype: parts
#     - group:
#       - methodname: sortAquisitionFunctionValues
#         methodtype: function
#         outputname: raiseMaterialsList
#         outputtype: function
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - methodname: ThonpsonSamplingaquisitionFunction
#         methodtype: parts
#         outputname: aquisitionFunctionValues
#         outputtype: parts
#     - group:
#       - methodname: sortAquisitionFunctionValues
#         methodtype: function
#         outputname: raiseMaterialsList
#         outputtype: function
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - outputname: BayesianLinearRegression
#         outputtype: parts
#     - group:
#       - methodname: apply_BayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#   - blockname: NewsetDescriptor-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - outputname: NewsetDescriptor
#         outputtype: parts
#     - group:
#       - methodname: apply_BayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - &id012
#         outputname: MaterialsKnowledge
#         outputtype: method
#     - group:
#       - &id013
#         methodname: randomGeneration
#         methodtype: method
#         outputname: NewsetCrystal
#         outputtype: parts
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - &id014
#         outputname: existingCrystals
#         outputtype: parts
#     - group:
#       - &id015
#         methodname: substituteElements
#         methodtype: function
#         outputname: NewsetCrystal
#         outputtype: parts
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - &id016
#         methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id001
#         methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - &id017
#         methodname: getParticularQuantities
#         methodtype: function
#         outputname: MaterialsKnowledge
#         outputtype: method
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - &id018
#         methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id019
#         methodname: TargetValuesFromDatabase
#         methodtype: parts
#         outputname: chooseTargetValues
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - &id020
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id021
#         methodname: CrystalsFromDatabase
#         methodtype: parts
#         outputname: existingCrystals
#         outputtype: parts
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - &id022
#         outputname: TrainingData
#         outputtype: parts
#     - group:
#       - &id023
#         methodname: NeuralNetworkRegression
#         outputname: RegressionModel
#         outputtype: parts
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - &id024
#         outputname: RegressionModel
#         outputtype: parts
#     - group:
#       - &id002
#         methodname: evaluateRegressionModel
#         methodtype: function
#         outputname: RegressionModelValues
#         outputtype: function
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - &id025
#         methodname: sortRegressionModelValues
#         methodtype: function
#         outputname: raiseMaterialsList
#         outputtype: function
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - &id003
#         outputname: NewsetCrystal
#         outputtype: parts
#     - group:
#       - &id004
#         methodname: CrystalToDescriptorAndRelationToTargetVariable(newSet)
#         methodtype: method
#         outputname: NewsetDescriptor
#         outputtype: parts
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - &id026
#         outputname: raiseMaterialsList
#         outputtype: function
#     - group:
#       - &id005
#         methodname: selectNoExperiment
#         methodtype: function
#         outputname: NoExperimentMaterialsList
#         outputtype: parts
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - &id006
#         methodname: MaterialSynthesis
#         methodtype: method
#         outputname: SynthesizedMaterils
#         outputtype: parts
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - &id007
#         methodname: measureTargetQuanitty
#         methodtype: function
#         outputname: newTargetValues
#         outputtype: parts
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - &id027
#         methodname: SelectSynthesizedTaretMaterialsIteratively
#         methodtype: function
#         outputname: newTargetMaterial
#         outputtype: parts
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - &id028
#         outputname: TargetCriterion
#         outputtype: parts
#     - group:
#       - &id029
#         methodname: TargetSelectionCriterion
#         methodtype: parts
#         outputname: getTargetSelectionCriterion
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - &id030
#         methodname: MaterialsDatabase
#         methodtype: method
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id031
#         methodname: storeInMaterialsDataBase
#         methodtype: function
#         outputname: RicherMaterialsDatabase
#         outputtype: parts
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - &id032
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id033
#         methodname: searchCrystalHavingTargetValuesfromDatabase
#         methodtype: function
#         outputname: chooseTrainingSetCrystal
#         outputtype: function
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - &id034
#         outputname: chooseMaterialsDatabase
#         outputtype: function
#     - group:
#       - &id008
#         methodname: queryCrysalDataHavingTarget
#         methodtype: function
#         outputname: CrystalHavingTargetValuesFromDatabase
#         outputtype: parts
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - &id035
#         methodname: chooseTargetValues
#         methodtype: parts
#         outputname: TargetValues
#         outputtype: parts
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - &id036
#         outputname: chooseTrainingSetCrystal
#         outputtype: function
#     - group:
#       - &id037
#         methodname: CrystalToDescriptorAndRelationToTargetVariable(trainingSet)
#         methodtype: method
#         outputname: TrainingSetDescriptorAndRelationToTargetVariable
#         outputtype: parts
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - &id038
#         outputname: TrainingSetDescriptorAndRelationToTargetVariable
#         outputtype: parts
#     - group:
#       - &id039
#         methodname: TrainingDataGeneration
#         methodtype: method
#         outputname: TrainingData
#         outputtype: parts
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - &id040
#         outputname: TrainingData
#         outputtype: parts
#     - group:
#       - &id009
#         methodname: fitBayesianLinearRegression
#         methodtype: function
#         outputname: BayesianLinearRegression
#         outputtype: parts
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - &id010
#         methodname: applyBayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - &id011
#         methodname: UCBaquisitionFunction
#         methodtype: parts
#         outputname: aquisitionFunctionValues
#         outputtype: parts
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - &id041
#         methodname: sortAquisitionFunctionValues
#         methodtype: function
#         outputname: raiseMaterialsList
#         outputtype: function
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - &id042
#         outputname: BayesianLinearRegression
#         outputtype: parts
#     - group:
#       - &id043
#         methodname: apply_BayesianLinearRegression
#         methodtype: function
#         outputname: PredictionMeanAndVariance
#         outputtype: parts
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
# ...
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043
#   - blockname: MaterialsKnowledge-randomGeneration-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id012
#     - group:
#       - *id013
#   - blockname: existingCrystals-substituteElements-NewsetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id014
#     - group:
#       - *id015
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id016
#     - group:
#       - *id001
#   - blockname: existingCrystals-getParticularQuantities-MaterialsKnowledge
#     order: workflow
#     list:
#     - group:
#       - *id001
#     - group:
#       - *id017
#   - blockname: chooseMaterialsDatabase-TargetValuesFromDatabase-chooseTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id018
#     - group:
#       - *id019
#   - blockname: chooseMaterialsDatabase-CrystalsFromDatabase-existingCrystals
#     order: workflow
#     list:
#     - group:
#       - *id020
#     - group:
#       - *id021
#   - blockname: TrainingData-NeuralNetworkRegression-RegressionModel
#     order: workflow
#     list:
#     - group:
#       - *id022
#     - group:
#       - *id023
#   - blockname: RegressionModel-evaluateRegressionModel-RegressionModelValues
#     order: workflow
#     list:
#     - group:
#       - *id024
#     - group:
#       - *id002
#   - blockname: RegressionModelValues-sortRegressionModelValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id002
#     - group:
#       - *id025
#   - blockname: NewsetCrystal-CrystalToDescriptorAndRelationToTargetVariable(newSet)-NewsetDescriptor
#     order: workflow
#     list:
#     - group:
#       - *id003
#     - group:
#       - *id004
#   - blockname: raiseMaterialsList-selectNoExperiment-NoExperimentMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id026
#     - group:
#       - *id005
#   - blockname: NoExperimentMaterialsList-MaterialSynthesis-SynthesizedMaterils
#     order: workflow
#     list:
#     - group:
#       - *id005
#     - group:
#       - *id006
#   - blockname: SynthesizedMaterils-measureTargetQuanitty-newTargetValues
#     order: workflow
#     list:
#     - group:
#       - *id006
#     - group:
#       - *id007
#   - blockname: newTargetValues-SelectSynthesizedTaretMaterialsIteratively-newTargetMaterial
#     order: workflow
#     list:
#     - group:
#       - *id007
#     - group:
#       - *id027
#   - blockname: TargetCriterion-TargetSelectionCriterion-getTargetSelectionCriterion
#     order: workflow
#     list:
#     - group:
#       - *id028
#     - group:
#       - *id029
#   - blockname: chooseMaterialsDatabase-storeInMaterialsDataBase-RicherMaterialsDatabase
#     order: workflow
#     list:
#     - group:
#       - *id030
#     - group:
#       - *id031
#   - blockname: chooseMaterialsDatabase-searchCrystalHavingTargetValuesfromDatabase-chooseTrainingSetCrystal
#     order: workflow
#     list:
#     - group:
#       - *id032
#     - group:
#       - *id033
#   - blockname: chooseMaterialsDatabase-queryCrysalDataHavingTarget-CrystalHavingTargetValuesFromDatabase
#     order: workflow
#     list:
#     - group:
#       - *id034
#     - group:
#       - *id008
#   - blockname: CrystalHavingTargetValuesFromDatabase-chooseTargetValues-TargetValues
#     order: workflow
#     list:
#     - group:
#       - *id008
#     - group:
#       - *id035
#   - blockname: chooseTrainingSetCrystal-CrystalToDescriptorAndRelationToTargetVariable(trainingSet)-TrainingSetDescriptorAndRelationToTargetVariable
#     order: workflow
#     list:
#     - group:
#       - *id036
#     - group:
#       - *id037
#   - blockname: TrainingSetDescriptorAndRelationToTargetVariable-TrainingDataGeneration-TrainingData
#     order: workflow
#     list:
#     - group:
#       - *id038
#     - group:
#       - *id039
#   - blockname: TrainingData-fitBayesianLinearRegression-BayesianLinearRegression
#     order: workflow
#     list:
#     - group:
#       - *id040
#     - group:
#       - *id009
#   - blockname: BayesianLinearRegression-applyBayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id009
#     - group:
#       - *id010
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: PredictionMeanAndVariance-UCBaquisitionFunction-aquisitionFunctionValues
#     order: workflow
#     list:
#     - group:
#       - *id010
#     - group:
#       - *id011
#   - blockname: aquisitionFunctionValues-sortAquisitionFunctionValues-raiseMaterialsList
#     order: workflow
#     list:
#     - group:
#       - *id011
#     - group:
#       - *id041
#   - blockname: BayesianLinearRegression-apply_BayesianLinearRegression-PredictionMeanAndVariance
#     order: workflow
#     list:
#     - group:
#       - *id042
#     - group:
#       - *id043

# %%
filename = "a.yml"
with open(filename,"w") as f:
    yaml.dump(wf,f)
    print("output to",filename)
# Out:
# output to a.yml

# %%
class FDTSearch(object):
    def __init__(self,wklist):
        self.wklist = wklist
        self.outputnamelist = self.store_outputnames(wklist)
        self.linklist = []

    def store_outputnames(self,wklist):
        namelist = []
        for node1, node2 in wklist:
            namelist.append(node1["outputname"])
            namelist.append(node2["outputname"])
        return list(set(namelist))

    def search_link(self,outputname1,outputname2,link=[]):
        #print("search_link",outputname1,outputname2)
        if len(outputname1)==0:
            return []
        #print("link",link)
        wklist = self.wklist
        subwklist = []
        wklistnext = []
        for node1, node2 in wklist:
            if node1["outputname"] == outputname1:
                wklistnext.append( node2["outputname"] )
                #subwklist.append( [node1,node2])
                if outputname2 is not None:
                    if node2["outputname"] == outputname2:
                        link.append([outputname1,outputname2])
                        #print("found link",link)
                        self.linklist.append(link)
                        return 

        wklistnext = list(set(wklistnext))
        #print("wklistnext",wklistnext)
        for newoutputname1 in wklistnext:
            newlink = copy.deepcopy(link)
            newlink.append([outputname1,newoutputname1])
            self.search_link(newoutputname1,outputname2,newlink)
            
    def get_nodes(self):
        selectedlist = []
        wklist = self.wklist
        for link in self.linklist:
            for output1,output2 in link:
                for wk in wklist:
                    node1,node2 = wk
                    if node1["outputname"] == output1 and \
                       node2["outputname"] == output2 :
                        selectedlist.append( [copy.deepcopy(node1),copy.deepcopy(node2)])
        return selectedlist

# %%
fdtsearch = FDTSearch(wfchain.wklist)

fdtsearch.search_link("TrainingData","raiseMaterialsList")

# %%
wksublist = fdtsearch.get_nodes()

# %%
wfsub = wklistToWF(wksublist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-aec3cdde881d> in <module>
# ----> 1 wfsub = wklistToWF(wksublist)
#
# NameError: name 'wklistToWF' is not defined

# %%
filename = "b.yml"
with open(filename,"w") as f:
    yaml.dump(wfsub,f)
    print("output to",filename)
